# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
df=pd.read_csv('Titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ports=pd.get_dummies(df.Embarked ,prefix="Embarked")
ports.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %%
from sklearn import preprocessing
#converting categorical data as number data using LabelEncoder

lc = preprocessing.LabelEncoder()

# %%
df["Embarked"] = lc.fit_transform(df["Embarked"])

# %%
df["Embarked"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
df=df.join(ports)
df.drop(["Embarked"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN       False       False        True
# 1      0          PC 17599  71.2833   C85        True       False       False
# 2      0  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %%
l = ["Embarked_C","Embarked_Q","Embarked_S","Sex"]
for i in l:
    df[i] = lc.fit_transform(df[i])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN           0           0           1
# 1          PC 17599  71.2833   C85           1           0           0
# 2  STON/O2. 3101282   7.9250   NaN           0           0           1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN           0           0           1
# 1          PC 17599  71.2833   C85           1           0           0
# 2  STON/O2. 3101282   7.9250   NaN           0           0           1
# ...

# %%
# y=df.Survived.copy()
# x=df.drop(["Survived"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked_C       0
# Embarked_Q       0
# Embarked_S       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN           0           0           1
# 1          PC 17599  71.2833   C85           1           0           0
# 2  STON/O2. 3101282   7.9250   NaN           0           0           1
# ...

# %%
y=df["Survived"]
x=df.drop(["Survived"],axis=1)

# %%
x1=df.drop(["Name","Cabin","Ticket","PassengerId"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Fare            0
# Embarked_C      0
# Embarked_Q      0
# Embarked_S      0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mode()[0],inplace=True)

# %%
df.head(20)
# Out:
#     Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked_C  \
# 0          0       3    1  22.0      1      0   7.2500           0
# 1          1       1    0  38.0      1      0  71.2833           1
# 2          1       3    0  26.0      0      0   7.9250           0
# 3          1       1    0  35.0      1      0  53.1000           0
# 4          0       3    1  35.0      0      0   8.0500           0
# 5          0       3    1  24.0      0      0   8.4583           0
# 6          0       1    1  54.0      0      0  51.8625           0
# 7          0       3    1   2.0      3      1  21.0750           0
# 8          1       3    0  27.0      0      2  11.1333           0
# 9          1       2    0  14.0      1      0  30.0708           1
# 10         1       3    0   4.0      1      1  16.7000           0
# 11         1       1    0  58.0      0      0  26.5500           0
# 12         0       3    1  20.0      0      0   8.0500           0
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked_C    0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size = 0.2 ,random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1=LogisticRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16140\3878483119.py in ?()
# ----> 1 model1.fit(X_train,y_train)
#
# E:\Anaconda\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# E:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1203             _dtype = np.float64
#    1204         else:
#    1205             _dtype = [np.float64, np.float32]
#    1206
# -> 1207         X, y = self._validate_data(
#    1208             X,
#    1209             y,
#    1210             accept_sparse="csr",
#
# ...

# %%
model.score(x_train,y_train)

# %%
model.score(x_test,y_test)

# %%
s
